# %%
#Calculating QBER
alice_key = [1,0,1,1,0,1,0,1]
bob_key = [1,0,0,1,0,1,1,1]
errors = 0
for i in range(len(alice_key)):
    if alice_key[i] != bob_key[i]:
        errors += 1
error_rate = (errors / len(alice_key)) * 100
print("Error Rate :", error_rate,"%")
# Out:
# Error Rate : 25.0 %

# %%
#Checking whether key is compromised or not
if error_rate > 12.9:
    print("Warning : Eavesdropper Detected!")
else:
    print("Secure Communication")
# Out:
# Warning : Eavesdropper Detected!
