# %%
#Intro to QML
from qiskit.circuit.library import ZZFeatureMap
from qiskit.circuit.library import RealAmplitudes
from qiskit_machine_learning.algorithms import VQC
from qiskit_algorithms.optimizers import COBYLA
from qiskit.primitives import StatevectorSampler
import numpy as np
feature_map = ZZFeatureMap(feature_dimension=2)
ansatz = RealAmplitudes(2, reps=2)
optimizer = COBYLA(maxiter=100)
sampler = StatevectorSampler()
vqc = VQC(
    sampler=sampler,
    feature_map=feature_map,
    ansatz=ansatz,
    optimizer=optimizer
)
training_features = np.array([
    [0, 0],
    [0, 1],
    [1, 0],
    [1, 1]
])
training_labels = np.array([0, 1, 1, 0])
test_features = np.array([
    [0.2, 0.1],
    [0.9, 0.8]
])
'''vqc.fit(training_features, training_labels)
predictions = vqc.predict(test_features)
print(predictions)'''
print("Training started...")
vqc.fit(training_features, training_labels)
print("Training completed!")
predictions = vqc.predict(test_features)
print("Predictions:", predictions)
# Out:
# /var/folders/_f/wz_y584176v1z1h8912l9jp40000gn/T/ipykernel_42322/4271784871.py:8: DeprecationWarning: The class ``qiskit.circuit.library.data_preparation._zz_feature_map.ZZFeatureMap`` is deprecated as of Qiskit 2.1. It will be removed in Qiskit 3.0. Use the zz_feature_map function as a replacement. Note that this will no longer return a BlueprintCircuit, but just a plain QuantumCircuit.
#   feature_map = ZZFeatureMap(feature_dimension=2)
# /var/folders/_f/wz_y584176v1z1h8912l9jp40000gn/T/ipykernel_42322/4271784871.py:9: DeprecationWarning: The class ``qiskit.circuit.library.n_local.real_amplitudes.RealAmplitudes`` is deprecated as of Qiskit 2.1. It will be removed in Qiskit 3.0. Use the function qiskit.circuit.library.real_amplitudes instead.
#   ansatz = RealAmplitudes(2, reps=2)
# No gradient function provided, creating a gradient function. If your Sampler requires transpilation, please provide a pass manager.
# Training started...
# Training completed!
# Predictions: [0 0]
